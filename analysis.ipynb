# %%
import pandas as pd

# %%
df = pd.read_csv('data/ktm_scraped_data.csv',names=['Brand','Model','Year','Kms','Price','Description','Location','Date'])

# %%
df.head()
# Out:
#   Brand         Model  Year    Kms   Price  \
# 0   KTM            RC  2017  11400  170000
# 1   KTM      Duke 200  2016  36600  110000
# 2   KTM  390 Duke ABS  2017   4700  220000
# 3   KTM  390 Duke ABS  2017   9370  210000
# 4   KTM            RC  2017   5000  250000
#
#                                          Description  \
# 0                           Bangalore housing board
# 1                 Ktm duke 200 very well maintained
# 2           Excellent condition bike sparingly used
# 3   Ktm duke 390 orange colour   Maintained in mi...
# 4                       I am selling my RC 390 bike
#
#                                             Location   Date
# 0                Kamakshipalya, Bengaluru, Karnataka  Today
# 1  Karanataka bangalore nagarabhavi 2nd stage, Be...  Today
# 2                  Milk Colony, Bengaluru, Karnataka  Today
# 3                    Attiguppe, Bengaluru, Karnataka  Today
# 4                 Rajaji Nagar, Bengaluru, Karnataka  Today

# %%
df[df.Model=='390 Duke ABS'].Kms.max()
# Out:
# 47000

# %%
df[df.Kms==95000]
# Out:
#     Brand         Model  Year    Kms   Price  \
# 235   KTM  390 Duke ABS  2018  95000  100000
#
#                                            Description  \
# 235   No problem 1020 2018 model Newton new condition
#
#                              Location       Date
# 235  Sakalawara, Bengaluru, Karnataka  Yesterday

# %%
df = df.drop([235],axis=0)

# %%
# %matplotlib inline

from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

# %%
# %matplotlib notebook
ax = plt.axes(projection='3d')

# # Data for a three-dimensional line
# zline = np.linspace(0, 15, 1000)
# xline = np.sin(zline)
# yline = np.cos(zline)
# ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
ydata = df[df.Model=='390 Duke ABS'].Price
xdata = df[df.Model=='390 Duke ABS'].Kms
zdata = df[df.Model=='390 Duke ABS'].Year
ax.scatter3D(xdata, ydata, zdata, c=zdata);
# Out:
# <img src="data:image/png;base64,..." width="629">

# %%
len(df[df.Model=='YZF R'])
# Out:
# 1

# %%
set(df.Model)
# Out:
# {'390 Duke ABS', 'Discover', 'Duke 200', 'Others', 'RC', 'YZF R'}

# %%
#price for real
# 390 Duke ABS = 291000
# duke 200 = 193000
# RC = 226000
